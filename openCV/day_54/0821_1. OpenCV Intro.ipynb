# %% [markdown]
# ## OpenCV(Open source Computer Vision library)
# 다양한 영상(이미지)나 동영상 처라에 사용되는 오픈 소스 라이브러리
# #### 세 가지 주요 컴퓨터 비전 작업
# - 분류
# 단일 레이블, 다중 레이블<br>
# - 분할
# 이미지<br>
# - 탐지
# 객체<br>
#
# #### Python 기반 주요 이미지 라이브러리
# - PIL(Python Image Library)
# - Scikit Image
# - OpenCV

# %%
import cv2
cv2.__version__
# Out:
# '4.8.0'

# %% [markdown]
# ### 1. 이미지 출력 - test code
# - pixabay에서 무료 이미지를 사용하여 실습 진행

# %%
img = cv2.imread('./img/straw.jpg')
cv2.imshow('img',img) # img라는 이름의 창에 img를 표시함
#cv2.waitKey(0) # 지정된 시간동안 사용자 키 입력 대기, default = 0(무한 대기)
cv2.waitKey(5000) # 5초동안 화면 보이기(단위는 ms)
cv2.destroyAllWindows() # 모든 창 닫기

# %%
img = cv2.imread('./img/straw.jpg')
cv2.imshow('img0',img) # img라는 이름의 창에 img를 표시함
key = cv2.waitKey(0)
print(key) # esc ==> 27(아스키코드 값)
cv2.destroyAllWindows() # 모든 창 닫기
# Out:
# 27

# %% [markdown]
# ### 2. 기본 입출력
# ##### 1. 이미지 읽기
# - CV2.IMREAD_COLOR : 컬러(BGR) 스케일, 기본값 1
# - CV2.IMREAD_UNCHANGED : 파일에 저장된 스케일 , 기본값 11
# - CV2. IMREAD_CRAYSCALED : 그레이 스케일, 기본값 - 0

# %%
import cv2
img_color = cv2.imread('./img/straw.jpg',cv2.IMREAD_COLOR)
img_unchanged = cv2.imread('./img/straw.jpg',cv2.IMREAD_UNCHANGED)
img_grayscale = cv2.imread('./img/straw.jpg',cv2.IMREAD_GRAYSCALE)
cv2.imshow('img1',img_color)
cv2.imshow('img2',img_unchanged)
cv2.imshow('img3',img_grayscale)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
img = cv2.imread('./img/straw.jpg')
img.shape # 가로, 세로, 채널
# Out:
# (427, 640, 3)

# %%
import cv2
img_file = "../Open_CV/insightbook.opencv_project_python-master/img/girl.jpg"
img = cv2.imread(img_file)
if img is not None:
    cv2.imshow('IMG',img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
else:
    print('No image file')

# %%
# 이미지 파일을 그레이 스케일로 화면에 표시
import cv2
img_file = "../Open_CV/insightbook.opencv_project_python-master/img/girl.jpg"
img = cv2.imread(img_file,cv2.IMREAD_GRAYSCALE)
if img is not None:
    cv2.imshow('IMG',img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
else:
    print('No image file')

# %%
# 이미지 저장하기

import cv2
img_file = "../Open_CV/insightbook.opencv_project_python-master/img/girl.jpg"
save_file = "./img/girl_gray.jpg"
img = cv2.imread(img_file, cv2.IMREAD_GRAYSCALE)
if img is not None : 
    cv2.imshow('IMG',img)
    cv2.imwrite(save_file, img) # 파일로 저장, 포멧은 확장자에 따름
    cv2.waitKey()
    cv2.destroyAllWindows()
else:
    print('No image file')

# %% [markdown]
# ### 3. 동영상 및 카메라 프레임 읽기
# - cap = cv2.VideoCapture(file_path 또는 index): 비디오 캡처 객체 생성자
#     - file_path: 동영상 파일 경로
#     - index： 카메라 장치 번호, 0부터 순차적으로 증가(0, 1,2,...)
#     - cap： VideoCapture 객체
# - ret = cap.isOpened()： 객체 초기화 확인
#     - ret: 초기화 여부, Tme/False
# - ret, img = cap.read()： 영상 프레임 읽기
#     - ret: 프레임 읽기 성공 또는 실패 여부, True/False
#     - img: 프레 임 이미 지, NumPy 배 열 또는 None
# - cap.set(id, value)： 프로퍼티 변경
# - cap.get(id)： 프로퍼티 확인
# - cap.release()： 캡처 자원 반납

# %%
# 동영상 파일 읽기
import cv2

video_file = '../Open_CV/insightbook.opencv_project_python-master/img/big_buck.avi'

cap = cv2.VideoCapture(video_file) # 동영상 캡처 객체 생성
if cap.isOpened():               # 캡처 객체 초기화 확인
    while True:
        ret, img = cap.read()   # 다음 프레임 읽기
        if ret:                 # 프레임 읽기 정상
            cv2.imshow('video_file',img)   # 화면 표시
            cv2.waitKey(25)           # 25ms 지연
        else:                       # 다음 프레임 읽을 수 없음
            break                       # 재생 완료
else:
    print("can't open video")           # 캡처 객체 초기화 실패

cap.release()                           # 캡처 자원 반납
cv2.destroyAllWindows()

# %%
import cv2

video_file = '../Open_CV/insightbook.opencv_project_python-master/img/big_buck.avi'

cap = cv2.VideoCapture(video_file) # 동영상 캡처 객체 생성
if cap.isOpened():     # 캡처 객체 초기화 확인
    fps = cap.get(cv2.CAP_PROP_FPS)
    delay = int(1000/fps)
    print("fps: %f, delay: %ddms"%(fps,delay))
    while True:
        ret, img = cap.read()   # 다음 프레임 읽기
        if ret:                 # 프레임 읽기 정상
            cv2.imshow('video_file',img)   # 화면 표시
            cv2.waitKey(25)           # 25ms 지연
        else:                       # 다음 프레임 읽을 수 없음
            break                       # 재생 완료
else:
    print("can't open video")           # 캡처 객체 초기화 실패

cap.release()                           # 캡처 자원 반납
cv2.destroyAllWindows()
# Out:
# fps: 24.000000, delay: 41dms

# %%
# 컴퓨터에 내장된 웹 캠 연결하고 화면으로 출력
import cv2

cap = cv2.VideoCapture(0)
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
print("Original width :%d, height:%d"%(width, height) )

cap.set(cv2.CAP_PROP_FRAME_WIDTH,320)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT,240)
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
print("Resized width :%d, height:%d" %(width,height))

if cap.isOpened():
    while True:
        ret, img = cap.read()
        if ret:
            cv2.imshow('camera',img)
            # ESC 키를 누르면 종료
            if cv2.waitKey(1) & 0xFF == 27:
                break
        else:
            print("no frame")
            break
else:
    print("can't open camera")
    
cap.release()
cv2.destroyAllWindows()
# Out:
# Original width :640, height:480
# Resized width :320, height:240

# %%
import cv2
# 마지막 장면을 캡쳐해서 이미지로 저장
cap = cv2.VideoCapture(0)
if cap.isOpened():
    while True:
        ret, frame = cap.read()
        if ret:
            cv2.imshow('camera',frame)
            if cv2.waitKey(1) & 0xFF == 27:
                cv2.imwrite('./img/Photo.jpg',frame)
                break
        else:
            print("no frame")
            break
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
# 켜진 순간부터 종료 순간까지 녹화
cap = cv2.VideoCapture(0)
if cap.isOpened():
    file_path = './record.avi'
    fps = 25.40
    fourcc = cv2.VideoWriter_fourcc(*'DIVX')
    width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
    height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
    size = (int(width),int(height))
    out = cv2.VideoWriter(file_path,fourcc, fps,size)
    while True:
        ret, frame = cap.read()
        if ret:
            cv2.imshow('camera',frame)
            out.write(frame)
            if cv2.waitKey(1) & 0xFF == 27:
                break
        else:
            print("no frame")
            break
    out.release()
else:
    print("can't open camera")
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### 4. 그림 그리기

# %%
# 그림판 역할을 할 이미지
import cv2
import numpy as np

img = np.full((500,500,3),255, dtype=np.uint8)
cv2.imwrite('./blank_500.jpg',img)
# Out:
# True

# %% [markdown]
# ##### 직선 그리기
# - 직선의 종류(line type)
#     - cv2.LINE_4： 4 연결 선 알고리즘(상하좌우 4방향으로 연결된 선)
#     - cv2.LINE_8： 8 연결 선 알고리즘(대각선을 포함한 8방향으로 연결된 선, default)
#     - cv2.LINE_AA： 안티 에일리어싱(antialiasing, 계단 현상 없는 선)

# %%
img = cv2.imread('./blank_500.jpg')
cv2.line(img, (50,50),(150,50),(255,0,0)) # 파란색
cv2.line(img,(200,50), (300,50),(0,255,0)) # 초록색
cv2.line(img,(350,50),(450,50),(0,0,255)) # 빨간색

cv2.line(img,(100,100),(400,100),(255,255,0),10) # 하늘색(파랑+초록) 10픽셀(두께)
cv2.line(img,(100,150),(400,150),(255,0,255),10) # 분홍색(파랑+빨강)
cv2.line(img,(100,200),(400,200),(0,255,255),10) # 노란색(초록+빨강)
cv2.line(img,(100,250),(400,250),(200,200,200),10) # 회색(파랑+초록+빨강)
cv2.line(img,(100,300),(400,300),(0,0,0),10) # 검은색

cv2.line(img,(100,350),(400,350),(0,0,255),20, cv2.LINE_4)
cv2.line(img,(100,400),(400,400),(0,0,255),20, cv2.LINE_8)
cv2.line(img,(100,450),(400,450),(0,0,255),20, cv2.LINE_AA)

cv2.line(img,(0,0),(500,500),(0,0,255))

cv2.imshow('lines',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### 사각형 그리기
# cv2.rectangle(img, start, end, color, [thickness, lineType])
# - img： 그림 그릴 대상 이미지, NumPy 배열
# - start： 사각형 시작 꼭짓점(x, y)
# - end： 사각형 끝 꼭짓점 (x, y)
# - color： 색상(Blue, Green, Red)
# - thickness： 선 두께
#     - -1: 채우기
# - lineType： 선 타입, cv2.line()과 동일

# %%
import cv2

img = cv2.imread('./blank_500.jpg')

cv2.rectangle(img,(50,50),(150,150),(255,0,0))
cv2.rectangle(img,(300,300),(100,100),(0,255,0),10)
cv2.rectangle(img,(450,200),(200,450),(0,0,255),-1)

cv2.imshow('rectangle',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### 다각형 그리기
# cv2.polylints(img, points,isClosed,color,[thickness,lineType])
# - isClosed : 닫힌 도형 여부, True - 닫힘, False - 열림

# %%
import cv2
import numpy as np

img = cv2.imread('./blank_500.jpg')

pts1 = np.array([[50,50],[150,150],[100,140],[200,240]],dtype=np.int32)
pts2 = np.array([[350,50],[250,200],[450,200]],dtype=np.int32)
pts3 = np.array([[150,300],[50,450],[250,450]],dtype=np.int32)
pts4 = np.array([[350,250],[450,350],[400,450],[300,450],[250,350]],dtype=np.int32)

cv2.polylines(img,[pts1],False,(255,0,0))   # 번개 모양 선 그리기
cv2.polylines(img,[pts2],False,(0,0,0),10)   # 닫히지 않은 삼각형
cv2.polylines(img,[pts3],True,(0,0,255),10)  # 삼각형 닫힌 도형
cv2.polylines(img,[pts4],True,(0,0,0))        # 오각형 닫힌 도형

cv2.imshow('polyline',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### 원, 타원, 호 그리기

# %%
import cv2

img = cv2.imread('./blank_500.jpg')
# 원점과 반지름을 가지는 원
cv2.circle(img,(150,150),100,(255,0,0))
cv2.circle(img,(300,150),70,(0,255,0),5)
cv2.circle(img,(400,150),50,(0,0,255),-1)

# 원점, 반지름, 회전, 0도부터 360도 그리기
cv2.ellipse(img, (50,300),(50,50),0,0,360,(0,0,255))

cv2.ellipse(img, (150,300),(50,50),0,0,180,(255,0,0))
cv2.ellipse(img, (200,300),(50,50),0,181,360,(0,0,255))

cv2.ellipse(img, (325,300),(75,50),0,0,360,(0,255,0))
cv2.ellipse(img, (450,300),(50,75),0,0,360,(255,0,255))

cv2.ellipse(img, (50,425),(50,75),15,0,360,(0,0,0))
cv2.ellipse(img, (200,425),(50,75),45,0,360,(0,0,0))

cv2.ellipse(img, (350,425),(50,75),45,0,180,(0,0,255))
cv2.ellipse(img, (400,425),(50,75),45,181,360,(255,0,0))

cv2.imshow('circle',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #####  글씨 그리기
# - fontFace : 글꼴
#     - cv2.FONT_HERSHEY_PLAIN : 산세리프체 작은 글꼴
#     - cv2.FONT_HERSHEY_SIMPLEX : 산세리프체 일반 글꼴
#     - cv2.FONT_HERSHEY_DUPLEX : 산세리프체 진한 글꼴
#     - cv2.FONT_HERSHEY_COMPLEX_SMALL : 세리프체 작은 글꼴
#     - cv2.FONT_HERSHEY_COMPLEX : 세리프체 일반 글꼴
#     - cv2.FONT_HERSHEY_TRIPLEX : 세리프체 진한 글꼴
#     - cv2.FONT_HERSHEY_SCRIPT_SIMPLEX : 필기체 산세리프 글꼴
#     - cv2.FONT_HERSHEY_SCRIPT_COMPLEX : 필기체 세리프 글꼴
#     - cv2.FONT_ITALIC : 이탤릭체 플래그

# %%
import cv2

img = cv2.imread('./blank_500.jpg')

# sans-serif small
cv2.putText(img, "Plain", (50, 30), cv2.FONT_HERSHEY_PLAIN, 1, (0, 0,0))            
# sans-serif normal
cv2.putText(img, "Simplex", (50, 70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0,0))        
# sans-serif bold
cv2.putText(img, "Duplex", (50, 110), cv2.FONT_HERSHEY_DUPLEX, 1, (0, 0,0))         
# sans-serif normall X2  ---①
cv2.putText(img, "Simplex", (200, 110), cv2.FONT_HERSHEY_SIMPLEX, 2, (0,0,250)) 

# serif small
cv2.putText(img, "Complex Small", (50, 180), cv2.FONT_HERSHEY_COMPLEX_SMALL,
            1, (0, 0,0))   
# serif normal
cv2.putText(img, "Complex", (50, 220), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0,0))
# serif bold
cv2.putText(img, "Triplex", (50, 260), cv2.FONT_HERSHEY_TRIPLEX, 1, (0, 0,0))               
# serif normal X2  ---②
cv2.putText(img, "Complex", (200, 260), cv2.FONT_HERSHEY_TRIPLEX, 2, (0,0,255))               

# hand-wringing sans-serif
cv2.putText(img, "Script Simplex", (50, 330), cv2.FONT_HERSHEY_SCRIPT_SIMPLEX,
            1, (0, 0,0)) 
# hand-wringing serif
cv2.putText(img, "Script Complex", (50, 370), cv2.FONT_HERSHEY_SCRIPT_COMPLEX,
            1, (0, 0,0)) 

# sans-serif + italic ---③
cv2.putText(img, "Plain Italic", (50, 430),
            cv2.FONT_HERSHEY_PLAIN | cv2.FONT_ITALIC, 1, (0, 0,0)) 
# sarif + italic
cv2.putText(img, "Complex Italic", (50, 470),
            cv2.FONT_HERSHEY_COMPLEX | cv2.FONT_ITALIC, 1, (0, 0,0)) 

cv2.imshow('draw text', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ### 5. Window Management

# %%
import csv
file_path = './insightbook.opencv_project_python-master/img/girl.jpg'
img = cv2.imread(file_path)
img_gray = cv2.imread(file_path,cv2.IMREAD_GRAYSCALE)
# WINDOW_AUTOSIZE = 이미지와 같은 크기, 창 크기 재조정 불가능
cv2.namedWindow('origin',cv2.WINDOW_AUTOSIZE)
# WINDOW_NORMAL = 임의의 크기, 사용자 창 크기 조정 가능
cv2.namedWindow('gray',cv2.WINDOW_NORMAL)

cv2.imshow('origin',img)
cv2.imshow('gray',img_gray)

cv2.moveWindow('origin',200,200)
cv2.moveWindow('gray',100,100)

cv2.waitKey(0)
cv2.resizeWindow('origin',200,200)
cv2.resizeWindow('gray',100,100)

cv2.waitKey(0)
cv2.destroyWindow('gray')
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 6. 이벤트 처리

# %% [markdown]
# ##### 키보드 이벤트

# %%
import cv2


img_file = './insightbook.opencv_project_python-master/img/girl.jpg'
img = cv2.imread(img_file)
title = 'IMG'
x,y = 100,100

while True:
    cv2.imshow(title, img)
    cv2.moveWindow(title, x,y)
    key = cv2.waitKey(0) & 0xFF
    print(key, chr(key))
    if key == ord('h'):
        x -= 10
    elif key == ord('j'):
        y += 10
    elif key == ord('k'):
        y -= 10
    elif key == ord('l'):
        x += 10
    elif key == ord('q') or key == 27:
        cv2.destroyAllWindows()
        break
    cv2.moveWindow(title,x,y)
# Out:
# 100 d
# 102 f
# 108 l
# 108 l
# 108 l
# 107 k
# 105 i
# 106 j
# 106 j
# 107 k
# 113 q

# %% [markdown]
# ##### 마우스 이벤트

# %%
import cv2

title = 'mouse event'
img = cv2.imread('./blank_500.jpg')
cv2.imshow(title,img)

def onMouse(event, x, y, flags, params):
    print(event,x,y)
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(img,(x,y),30,(0,0,0), -1)
        cv2.imshow(title,img)
        
cv2.setMouseCallback(title,onMouse)

while True:
    if cv2.waitKey(0) & 0xFF == 27:
        break

cv2.destroyAllWindows()
# Out:
# 0 347 235
# 0 347 235
# 0 347 235
# 0 347 235
# 0 347 235
# 0 347 235
# 0 346 235
# 0 346 234
# 0 344 234
# 0 341 233
# 0 335 232
# 0 327 229
# 0 317 227
# 0 305 223
# 0 289 220
# 0 273 216
# 0 254 211
# 0 233 205
# 0 211 199
# 0 187 195
# 0 166 189
# 0 144 183
# 0 127 178
# 0 113 173
# 0 101 170
# 0 93 167
# 0 86 166
# 0 81 164
# 0 78 163
# 0 77 163
# 0 76 163
# 0 76 162
# 0 76 161
# 0 77 161
# 0 77 160
# 0 79 159
# 0 82 157
# 0 84 156
# 0 86 154
# 0 88 154
# 0 90 152
# 0 93 151
# 0 95 150
# 0 96 149
# 0 98 147
# 0 99 146
# 0 100 145
# 0 100 144
# 0 101 143
# 0 102 143
# 0 102 142
# 0 102 142
# 0 102 141
# 1 102 141
# 4 102 141
# 0 102 141
# 0 103 141
# 0 103 140
# 0 104 140
# 0 104 140
# 0 106 140
# 0 108 139
# 0 110 138
# 0 113 138
# 0 115 137
# 0 119 137
# 0 123 135
# 0 127 134
# 0 131 134
# 0 134 134
# 0 140 134
# 0 144 134
# 0 147 134
# 0 151 134
# 0 155 134
# 0 159 134
# 0 162 134
# 0 165 134
# 0 168 134
# 0 170 134
# 0 173 134
# 0 175 134
# 0 176 134
# 0 178 134
# 0 179 134
# ...

# %%
import cv2
title = 'mouse event'
img = cv2.imread('./blank_500.jpg')
cv2.imshow(title,img)
colors = {'black':(0,0,0),'red': (0,0,255),'blue':(255,0,0), 'green': (0,255,0) }
def onMouse(event, x, y, flags, param):
    print(event, x, y, flags)
    color = colors['black']
    if event == cv2.EVENT_LBUTTONDOWN:
        if flags & cv2.EVENT_FLAG_CTRLKEY and flags & cv2.EVENT_FLAG_SHIFTKEY :
            color = colors['green']
        elif flags & cv2.EVENT_FLAG_SHIFTKEY :
            color = colors['blue']
        elif flags & cv2.EVENT_FLAG_CTRLKEY :
            color = colors['red']
        cv2.circle(img, (x,y), 30, color, -1)
        cv2.imshow(title, img)
cv2.setMouseCallback(title, onMouse)
while True:
    if cv2.waitKey(0) & 0xFF == 27:
        break
cv2.destroyAllWindows()
# Out:
# 0 194 5 0
# 0 192 13 0
# 0 189 22 0
# 0 187 30 0
# 0 184 37 0
# 0 182 44 0
# 0 180 50 0
# 0 178 56 0
# 0 176 62 0
# 0 174 66 0
# 0 171 71 0
# 0 168 74 0
# 0 166 79 0
# 0 164 82 0
# 0 162 86 0
# 0 159 90 0
# 0 156 94 0
# 0 153 98 0
# 0 150 103 0
# 0 147 107 0
# 0 144 111 0
# 0 140 116 0
# 0 137 120 0
# 0 135 124 0
# 0 132 129 0
# 0 129 134 0
# 0 126 137 0
# 0 124 141 0
# 0 122 143 0
# 0 121 145 0
# 0 119 146 0
# 0 119 147 0
# 0 119 148 0
# 0 119 147 0
# 0 119 146 0
# 0 119 145 0
# 0 119 144 0
# 0 119 143 0
# 0 119 141 0
# 0 119 140 0
# 0 118 138 0
# 0 118 136 0
# 0 117 134 0
# 0 117 132 0
# 0 116 128 0
# 0 116 126 0
# 0 116 123 0
# 0 115 120 0
# 0 114 117 0
# 0 114 114 0
# 0 113 112 0
# 0 113 110 0
# 0 112 108 0
# 0 111 104 0
# 0 111 103 0
# 0 110 101 0
# 0 110 100 0
# 0 110 99 0
# 0 109 98 0
# 0 108 96 0
# 0 108 95 0
# 0 108 95 0
# 0 108 95 0
# 0 108 94 0
# 0 107 94 0
# 0 107 93 0
# 1 107 93 1
# 0 107 93 1
# 0 107 92 1
# 4 107 92 0
# 0 107 92 0
# 0 108 92 0
# 0 108 93 0
# 0 110 94 0
# ...

# %% [markdown]
# ##### 트랙바

# %%
import cv2
import numpy as np

win_name = "Trackbar"

img = cv2.imread('./blank_500.jpg')
cv2.imshow(win_name,img)

def onChange(x):
    r = cv2.getTrackbarPos('R',win_name)
    g = cv2.getTrackbarPos('G',win_name)
    b = cv2.getTrackbarPos('B',win_name)
    
    print(x,r,g,b)
    img[:] = [b,g,r]
    cv2.imshow(win_name,img)
    
cv2.createTrackbar('R',win_name, 0,255,onChange)
cv2.createTrackbar('G',win_name, 0,255,onChange)
cv2.createTrackbar('B',win_name, 0,255,onChange)

while True:
    if cv2.waitKey(1) & 0xFF == 27:
        break
cv2.destroyAllWindows()
# Out:
# 1 1 0 0
# 3 3 0 0
# 4 4 0 0
# 6 6 0 0
# 7 7 0 0
# 10 10 0 0
# 12 12 0 0
# 13 13 0 0
# 14 14 0 0
# 16 16 0 0
# 22 22 0 0
# 26 26 0 0
# 28 28 0 0
# 33 33 0 0
# 36 36 0 0
# 42 42 0 0
# 48 48 0 0
# 51 51 0 0
# 56 56 0 0
# 60 60 0 0
# 63 63 0 0
# 66 66 0 0
# 70 70 0 0
# 73 73 0 0
# 77 77 0 0
# 80 80 0 0
# 83 83 0 0
# 87 87 0 0
# 90 90 0 0
# 92 92 0 0
# 95 95 0 0
# 100 100 0 0
# 102 102 0 0
# 104 104 0 0
# 106 106 0 0
# 107 107 0 0
# 109 109 0 0
# 111 111 0 0
# 112 112 0 0
# 111 111 0 0
# 110 110 0 0
# 109 109 0 0
# 108 108 0 0
# 107 107 0 0
# 106 106 0 0
# 105 105 0 0
# 103 103 0 0
# 100 100 0 0
# 98 98 0 0
# 97 97 0 0
# 94 94 0 0
# 93 93 0 0
# 91 91 0 0
# 90 90 0 0
# 88 88 0 0
# 84 84 0 0
# 83 83 0 0
# 82 82 0 0
# 83 83 0 0
# 84 84 0 0
# 88 88 0 0
# 90 90 0 0
# 91 91 0 0
# 92 92 0 0
# 93 93 0 0
# 95 95 0 0
# 97 97 0 0
# 100 100 0 0
# 102 102 0 0
# 103 103 0 0
# 104 104 0 0
# 106 106 0 0
# 110 110 0 0
# 113 113 0 0
# 114 114 0 0
# 119 119 0 0
# 120 120 0 0
# 121 121 0 0
# 122 122 0 0
# ...
