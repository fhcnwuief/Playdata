# %%
import pandas as pd
import numpy as np


ball = pd.read_csv('../../../../Downloads/ball.csv')
ball
# Out:
#               Player Pos   3P   2P   TRB  AST  STL  BLK
# 0       Alex Abrines  SG  1.4  0.6   1.3  0.6  0.5  0.1
# 1       Steven Adams   C  0.0  4.7   7.7  1.1  1.1  1.0
# 2      Alexis Ajinca   C  0.0  2.3   4.5  0.3  0.5  0.6
# 3     Chris Andersen   C  0.0  0.8   2.6  0.4  0.4  0.6
# 4        Will Barton  SG  1.5  3.5   4.3  3.4  0.8  0.5
# ..               ...  ..  ...  ...   ...  ...  ...  ...
# 95    Nikola Vucevic   C  0.3  6.1  10.4  2.8  1.0  1.0
# 96       Dwyane Wade  SG  0.8  6.2   4.5  3.8  1.4  0.7
# 97      Dion Waiters  SG  1.8  4.3   3.3  4.3  0.9  0.4
# 98  Hassan Whiteside   C  0.0  7.0  14.1  0.7  0.7  2.1
# 99      Lou Williams  SG  2.0  3.3   2.5  3.0  1.0  0.2
#
# [100 rows x 8 columns]

# %%
print('키 : \n{}'.format(ball.keys()))
# Player : 이름
# Pos: 플레이어의 포지션을 나타냅니다. 'SG' 는 '슈팅가드' 'C'는 '센터'를 의미
# 3P : 3점슛 성공 횟수
# 2P : 2점슛 성공 횟수
# TRB: 리바운드 성공 횟수
# AST: 어시스트 성공 횟수
# STL: 스틸 성공 횟수
# BLK: 블로킹 성공 횟수
# Out:
# 키 :
# Index(['Player', 'Pos', '3P', '2P', 'TRB', 'AST', 'STL', 'BLK'], dtype='object')

# %%
import matplotlib.pyplot as plt
# 회귀일 경우 대부분 임의의 숫자이므로 특성 하나만 사용
# target 값 perch_weight를 y로 둠
plt.scatter(perch_length,perch_weight)
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
ballsg = ball[ball['Pos']=='SG']

# %%
ballc = ball[ball['Pos']=='C']

# %%
print(ballsg.head())
print(ballc.head())
# SG 데이터랑 C 데이터를 분리햇음
# Out:
#             Player Pos   3P   2P  TRB  AST  STL  BLK
# 0     Alex Abrines  SG  1.4  0.6  1.3  0.6  0.5  0.1
# 4      Will Barton  SG  1.5  3.5  4.3  3.4  0.8  0.5
# 5    Nicolas Batum  SG  1.8  3.4  6.2  5.9  1.1  0.4
# 6     Bradley Beal  SG  2.9  5.4  3.1  3.5  1.1  0.3
# 7  Marco Belinelli  SG  1.4  2.2  2.4  2.0  0.6  0.1
#              Player Pos   3P   2P  TRB  AST  STL  BLK
# 1      Steven Adams   C  0.0  4.7  7.7  1.1  1.1  1.0
# 2     Alexis Ajinca   C  0.0  2.3  4.5  0.3  0.5  0.6
# 3    Chris Andersen   C  0.0  0.8  2.6  0.4  0.4  0.6
# 9   Bismack Biyombo   C  0.0  2.2  7.0  0.9  0.3  1.1
# 10      Tarik Black   C  0.0  2.2  5.1  0.6  0.4  0.7

# %%
ballc.count()
# Out:
# Player    50
# Pos       50
# 3P        50
# 2P        50
# TRB       50
# AST       50
# STL       50
# BLK       50
# dtype: int64

# %%
ballc[ballc['3P']==0.0].count()
# Out:
# Player    32
# Pos       32
# 3P        32
# 2P        32
# TRB       32
# AST       32
# STL       32
# BLK       32
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(ballsg['3P'], ballc['3P'])
plt.xlabel('ballsg')
plt.ylabel('ballc')
plt.show()

# %%
print("data의 크기 : {}".format(ballsg.shape))
# Out:
# data의 크기 : (50, 8)

# %%
from sklearn.model_selection import train_test_split

train_input, test_input, train_target, test_target = train_test_split(ballc,ballsg,test_size=0.2,random_state=42)

print(train_input.shape, test_input.shape)
# Out:
# (40, 8) (10, 8)

# %%
print(len(ballc['3P']))
# default = 75:25
print(56*0.2)
# print(56*0.25)
# Out:
# 50
# 11.200000000000001

# %%
print("train_input 크기:{}".format(train_input.shape))
print("train_target 크기:{}".format(train_target.shape))
# Out:
# train_input 크기:(40, 8)
# train_target 크기:(40, 8)

# %%
ball_dataframe = pd.DataFrame(train_target)

# %%
ball_dataframe
# Out:
#                       Player Pos   3P   2P  TRB  AST  STL  BLK
# 21           Jordan Crawford  SG  1.9  3.6  1.8  3.0  0.6  0.1
# 7            Marco Belinelli  SG  1.4  2.2  2.4  2.0  0.6  0.1
# 78           Josh Richardson  SG  1.4  2.4  3.2  2.6  1.1  0.7
# 14  Kentavious Caldwell-Pope  SG  2.0  2.9  3.3  2.5  1.2  0.2
# 6               Bradley Beal  SG  2.9  5.4  3.1  3.5  1.1  0.3
# 12              Devin Booker  SG  1.9  5.9  3.2  3.4  0.9  0.3
# 82                J.R. Smith  SG  2.3  0.7  2.8  1.5  1.0  0.3
# 94          Denzel Valentine  SG  1.3  0.5  2.6  1.1  0.5  0.1
# 96               Dwyane Wade  SG  0.8  6.2  4.5  3.8  1.4  0.7
# 28             Evan Fournier  SG  1.9  4.1  3.1  3.0  1.0  0.1
# 17           Jordan Clarkson  SG  1.4  4.4  3.0  2.6  1.1  0.1
# 32             Manu Ginobili  SG  1.3  1.2  2.3  2.7  1.2  0.2
# 49               Rodney Hood  SG  1.9  2.7  3.4  1.6  0.6  0.2
# 72              Jamal Murray  SG  1.4  2.2  2.6  2.1  0.6  0.3
# ...
